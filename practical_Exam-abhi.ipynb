# %%
#Load the Student Performance dataset into a pandas DataFrame. This dataset is available in classroom.  
#Write code show the first few rows of the dataset.
import pandas as pd

df = pd.read_csv("student_performance.csv") 

print(df.head())
# Out:
#    StudentID  G1  G2  G3      Mjob     Fjob  age address  studytime  failures  \
# 0          1   6   2   2   teacher  at_home   21   rural          3         1
# 1          2  19  11  18    health  teacher   18   rural          1         1
# 2          3  14   7  19    health    other   20   urban          1         1
# 3          4  10   2   6  services   health   21   urban          3         1
# 4          5   7   0  19    health   health   18   rural          4         1
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0        no    yes  yes        yes     yes    yes       no      yes
# 1        no     no   no         no     yes     no       no       no
# 2       yes    yes  yes         no      no     no      yes      yes
# 3       yes     no  yes         no     yes     no       no       no
# 4        no     no  yes         no     yes    yes      yes       no

# %%
#Write code to display the statistical information on  Student Performance dataset   (information about the data types of each column).

import pandas as pd

df = pd.read_csv('student_performance.csv')  

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   100 non-null    int64
#  1   G1          100 non-null    int64
#  2   G2          100 non-null    int64
#  3   G3          100 non-null    int64
#  4   Mjob        100 non-null    object
#  5   Fjob        100 non-null    object
#  6   age         100 non-null    int64
#  7   address     100 non-null    object
#  8   studytime   100 non-null    int64
#  9   failures    100 non-null    int64
#  10  schoolsup   100 non-null    object
#  11  famsup      100 non-null    object
#  12  paid        100 non-null    object
#  13  activities  100 non-null    object
#  14  nursery     100 non-null    object
#  15  higher      100 non-null    object
#  16  internet    100 non-null    object
#  17  romantic    100 non-null    object
# dtypes: int64(7), object(11)
# memory usage: 14.2+ KB
# None

# %%
#Write code to find number of rows with missing data in the dataset.

import pandas as pd


df = pd.read_csv('student_performance.csv')  


rows_with_missing_data = df.isnull().sum(axis=1)  
num_rows_with_missing_data = (rows_with_missing_data > 0).sum()  

print(f"Number of rows with missing data: {num_rows_with_missing_data}")
# Out:
# Number of rows with missing data: 0

# %%
#Write code to find mean, mode of the number of runs scored by top 10 players. IPL dataset is available in classroom

import pandas as pd

df = pd.read_csv('ipl_matches_smalldata.csv')  

top_10_players = df.nlargest(10, 'total_runs')

mean_runs = top_10_players['total_runs'].mean()

mode_runs = top_10_players['total_runs'].mode()[0]  

print(f"Mean of runs scored by top 10 players: {mean_runs}")
print(f"Mode of runs scored by top 10 players: {mode_runs}")
# Out:
# Mean of runs scored by top 10 players: 6.1
# Mode of runs scored by top 10 players: 6

# %%
#Write code to filter players who have scored more than 500 runs

import pandas as pd

df = pd.read_csv('ipl_matches_smalldata.csv') 

players_above_500_runs = df[df['total_runs'] > 500]

print(players_above_500_runs)
# Out:
# Empty DataFrame
# Columns: [match_id, inning, batting_team, bowling_team, over, ball, batter, bowler, non_striker, batsman_runs, extra_runs, total_runs, extras_type, is_wicket, player_dismissed, dismissal_kind, fielder]
# Index: []

# %%
#Write code to create a bar chart to visualize the number of runs by top 10 players
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('ipl_matches_smalldata.csv')  

top_10_players = df.nlargest(10, 'total_runs')


plt.figure(figsize=(10, 6)) 
plt.bar(top_10_players['batter'], top_10_players['total_runs'], color='skyblue')


plt.xlabel('batter')
plt.ylabel('Runs Scored')
plt.title('Top 10 Players by Runs Scored')


plt.xticks(rotation=45)


plt.tight_layout()  
plt.show()

# %%
#Write a Python program using OpenCV functions to read an image from a file and display it using OpenCV
import cv2

image = cv2.imread('generative-ai.webp')  

if image is None:
    print("Error: Unable to load image.")
else:
  
    cv2.imshow('Image', image)

   
    cv2.waitKey(0)


    cv2.destroyAllWindows()

# %%
#Write a Python program using OpenCV functions to Find the shape (dimensions) of the image. 
import cv2

image = cv2.imread('generative-ai.webp')  

if image is None:
    print("Error: Unable to load image.")
else:

    height, width, channels = image.shape

    print(f"Image dimensions: {width}x{height}")
    print(f"Number of channels: {channels}")
# Out:
# Image dimensions: 1000x564
# Number of channels: 3

# %%
#Write a Python program using OpenCV functions to Resize the image to dimensions of 400x256 pixels.
import cv2

image = cv2.imread('generative-ai.webp')  

if image is None:
    print("Error: Unable to load image.")
else:
    
    resized_image = cv2.resize(image, (400, 256))

    
    cv2.imshow('Resized Image', resized_image)

    cv2.waitKey(0)

    cv2.destroyAllWindows()

# %%
#Write a Python program using OpenCV functions to Display the resized image.
import cv2

image = cv2.imread('generative-ai.webp') 

if image is None:
    print("Error: Unable to load image.")
else:
    
    resized_image = cv2.resize(image, (600, 356))

    
    cv2.imshow('Resized Image', resized_image)

    cv2.waitKey(0)

    cv2.destroyAllWindows()

# %%
#Write a Python program using OpenCV functions to Flip the image horizontally and vertically

import cv2

image = cv2.imread('generative-ai.webp')  

if image is None:
    print("Error: Unable to load image.")
else:
    
    flipped_horizontal = cv2.flip(image, 1)

    flipped_vertical = cv2.flip(image, 0)

   
    flipped_both = cv2.flip(image, -1)

    
    cv2.imshow('Original Image', image)
    cv2.imshow('Flipped Horizontally', flipped_horizontal)
    cv2.imshow('Flipped Vertically', flipped_vertical)
    cv2.imshow('Flipped Horizontally and Vertically', flipped_both)

    cv2.waitKey(0)

    cv2.destroyAllWindows()

# %%
#Write a python program to load dataset related to tips given in restaurant and display a pie chart to compare percentage of people in smoking area vs non smoking area
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "tips" dataset from seaborn
tips = sns.load_dataset('tips')

# Count the number of people in the smoking vs non-smoking areas
area_counts = tips['smoker'].value_counts()

# Create a pie chart to compare the percentages of people in smoking area vs non-smoking area
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(area_counts, labels=area_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], startangle=140)

# Add a title to the pie chart
plt.title('Percentage of People in Smoking vs Non-Smoking Areas')

# Display the pie chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 2
#       1 #Write a python program to load dataset related to tips given in restaurant and display a pie chart to compare percentage of people in smoking area vs non smoking area
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#       5 # Load the "tips" dataset from seaborn
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# Load the "tips" dataset from seaborn
tips = sns.load_dataset('tips')

# Display the first few rows of the dataset
print(tips.head())

# Optionally, you can display more information about the dataset
print("\nDataset Information:")
print(tips.info())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
#display a pie chart to compare percentage of people in smoking area vs non smoking area

import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

area_counts = tips['smoker'].value_counts()

plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(area_counts, labels=area_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], startangle=140)

plt.title('Percentage of People in Smoking vs Non-Smoking Areas')

plt.show()

# %%
# !pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install nltk wordcloud matplotlib
# Out:
# Requirement already satisfied: nltk in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: wordcloud in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: click in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\abhis\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: colorama in c:\users\abhis\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)

# %%
#Write python program using nltk library to load the text on topic of your choice and generate a word cloud from it. 
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

text = """
Artificial Intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.
"""

tokens = word_tokenize(text.lower())

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words and word.isalpha()]


filtered_text = ' '.join(filtered_tokens)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
